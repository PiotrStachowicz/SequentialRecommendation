# %% [markdown]
# # Preprocessed Beauty analysis

# %%
import pandas as pd
import csv
from tqdm import tqdm

# %% [markdown]
# ## 1. Read .inter file

# %%
df = pd.read_csv('./Amazon_Beauty.inter', sep='\t')

df.head(5)
# Out:
#    user_id:token  item_id:token  rating:float  timestamp:float
# 0              0              0           1.0    1616743454733
# 1              0              1           1.0    1614915977684
# 2              0              2           5.0    1612052493701
# 3              0              3           1.0    1609700981786
# 4              0              4           3.0    1581313195358

# %%
print(f"Number of unique items: {df['item_id:token'].nunique()}")
print(f"Number of unique users: {df['user_id:token'].nunique()}")
print(df.shape)
# Out:
# Number of unique items: 1028731
# Number of unique users: 11325787
# (23911390, 4)

# %% [markdown]
# ## 2. K-core filtering

# %%
while True:
    shp = df.shape

    df = df.groupby("user_id:token").filter(lambda x: len(x) >= 5)
    df = df.groupby("item_id:token").filter(lambda x: len(x) >= 5)

    if df.shape == shp:
        break

    print(f"Number of unique items: {df['item_id:token'].nunique()}")
    print(f"Number of unique users: {df['user_id:token'].nunique()}")
    print(df.shape)
# Out:
# Number of unique items: 224371
# Number of unique users: 888536
# (7417373, 4)
# Number of unique items: 212441
# Number of unique users: 759918
# (6900071, 4)
# Number of unique items: 211525
# Number of unique users: 751586
# (6863354, 4)
# Number of unique items: 211456
# Number of unique users: 750888
# (6860294, 4)
# Number of unique items: 211451
# Number of unique users: 750836
# (6860067, 4)
# Number of unique items: 211451
# Number of unique users: 750834
# (6860059, 4)

# %% [markdown]
# ## 3. Analysis

# %% [markdown]
# ### 3.1 Number of unique users & items

# %%
print(f"Number of unique items: {df['item_id:token'].nunique()}")
print(f"Number of unique users: {df['user_id:token'].nunique()}")
print(f"Number of unique reviews: {df.shape[0]}")
# Out:
# Number of unique items: 211451
# Number of unique users: 750834
# Number of unique reviews: 6860059

# %% [markdown]
# ### 3.2 Averages

# %%
print(f"Average rating: {df['rating:float'].sum() / df.shape[0]}")
print(f"Average interaction of user: {df.shape[0] / df['user_id:token'].nunique()}")
print(f"Average interaction of item: {df.shape[0] / df['item_id:token'].nunique()}")
# Out:
# Average rating: 4.235185295053585
# Average interaction of user: 9.136585450312586
# Average interaction of item: 32.44278343445999

# %% [markdown]
# ### 3.3 Interaction matrix sparsity

# %%
print(f"Matrix sparsity: {(1.0 - (df.shape[0] / (df['item_id:token'].nunique() * df['user_id:token'].nunique())))*100}%")
#print(f"Matrix sparsity: {(1.0 - (df.shape[0] / (1587220 * (df['user_id:token'].nunique() + 1))))*100}%")
# Out:
# Matrix sparsity: 99.99567910038245%
