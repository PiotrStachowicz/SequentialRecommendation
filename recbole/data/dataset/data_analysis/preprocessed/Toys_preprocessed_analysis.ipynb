# %% [markdown]
# # Preprocessed Toys_and_Outdoors analysis

# %%
import pandas as pd
import csv
from tqdm import tqdm

# %%
df = pd.read_csv('./Amazon_Toys_and_Games.inter', sep='\t')

df.head(5)
# Out:
#    user_id:token  item_id:token  rating:float  timestamp:float
# 0              0              0           5.0    1677939664713
# 1              0              1           3.0    1639855230760
# 2              0              2           5.0    1580949719154
# 3              1              3           5.0    1471542588000
# 4              1              4           3.0    1471541996000

# %%
print(f"Number of unique items: {df['item_id:token'].nunique()}")
print(f"Number of unique users: {df['user_id:token'].nunique()}")
print(df.shape)
# Out:
# Number of unique items: 890667
# Number of unique users: 8116226
# (16260406, 4)

# %% [markdown]
# ### K-core filtering

# %%
while True:
    shp = df.shape

    df = df.groupby("user_id:token").filter(lambda x: len(x) >= 5)
    df = df.groupby("item_id:token").filter(lambda x: len(x) >= 5)

    if df.shape == shp:
        break

    print(f"Number of unique items: {df['item_id:token'].nunique()}")
    print(f"Number of unique users: {df['user_id:token'].nunique()}")
    print(df.shape)
# Out:
# Number of unique items: 184919
# Number of unique users: 567570
# (4506196, 4)
# Number of unique items: 168462
# Number of unique users: 458954
# (4066348, 4)
# Number of unique items: 166335
# Number of unique users: 447917
# (4014749, 4)
# Number of unique items: 165972
# Number of unique users: 446391
# (4007263, 4)
# Number of unique items: 165918
# Number of unique users: 446125
# (4005988, 4)
# Number of unique items: 165911
# Number of unique users: 446096
# (4005844, 4)
# Number of unique items: 165910
# Number of unique users: 446091
# (4005820, 4)
# Number of unique items: 165910
# Number of unique users: 446090
# (4005816, 4)

# %% [markdown]
# ### Number of unique users & items

# %%
print(f"Number of unique items: {df['item_id:token'].nunique()}")
print(f"Number of unique users: {df['user_id:token'].nunique()}")
print(f"Number of unique reviews: {df.shape[0]}")
# Out:
# Number of unique items: 165910
# Number of unique users: 446090
# Number of unique reviews: 4005816

# %% [markdown]
# ### Averages

# %%
print(f"Average rating: {df['rating:float'].sum() / df.shape[0]}")
print(f"Average interaction of user: {df.shape[0] / df['user_id:token'].nunique()}")
print(f"Average interaction of item: {df.shape[0] / df['item_id:token'].nunique()}")
# Out:
# Average rating: 4.460969500346496
# Average interaction of user: 8.979838149252393
# Average interaction of item: 24.144512084865287

# %% [markdown]
# ### Interaction matrix sparsity

# %%
print(f"Matrix sparsity: {(1.0 - (df.shape[0] / (df['item_id:token'].nunique() * df['user_id:token'].nunique())))*100}%")
#print(f"Matrix sparsity: {(1.0 - (df.shape[0] / (1587220 * (df['user_id:token'].nunique() + 1))))*100}%")
# Out:
# Matrix sparsity: 99.99458752447154%
