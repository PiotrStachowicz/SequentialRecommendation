# %%
# Otwórz plik do odczytu
with open("/Users/jakubmalczak/Downloads/Amazon_Sports_and_Outdoors.image", "r", encoding="utf-8") as f:
    # Pobierz dwie pierwsze linie
    for i in range(2):
        line = f.readline().strip()          # usuń \n na końcu
        parts = line.split()                 # domyślnie splituje po spacji
        print(f"Linia {i+1}: {parts}")
        print(f"Długość tablicy: {len(parts)}")
# Out:
# Linia 1: ['ent_id:token', 'ent_emb:float_seq']
# Długość tablicy: 2
# ...
