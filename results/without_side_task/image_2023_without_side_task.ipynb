# %%
# !sudo apt update
# !sudo apt install python3.9 python3.9-venv
# !python3.9 -m venv myenv
# !source myenv/bin/activate
# !./myenv/bin/pip install --upgrade pip
# !./myenv/bin/pip install numpy==1.20.3 scipy==1.6.3 tensorboard==2.7.0
# !./myenv/bin/pip install torch==1.8.1+cu111 -f https://download.pytorch.org/whl/torch_stable.html
# !./myenv/bin/pip install PyYAML
# !./myenv/bin/pip install colorlog
# !./myenv/bin/pip install protobuf==3.19.0
# !./myenv/bin/pip install six
# !./myenv/bin/pip install colorama
# !./myenv/bin/pip install scikit-learn
# !./myenv/bin/pip install pandas==1.2.4
# !./myenv/bin/pip install tqdm
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,085 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,154 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,516 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,269 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,202 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [5,282 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,575 kB]
# Get:18 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,772 kB]
# Fetched 32.3 MB in 5s (7,097 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 36 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.9-minimal libpython3.9-stdlib python3.9-distutils
#   python3.9-lib2to3 python3.9-minimal
# Suggested packages:
#   binfmt-support
# The following NEW packages will be installed:
#   libpython3.9-minimal libpython3.9-stdlib python3.9 python3.9-distutils
#   python3.9-lib2to3 python3.9-minimal python3.9-venv
# 0 upgraded, 7 newly installed, 0 to remove and 36 not upgraded.
# Need to get 7,816 kB of archives.
# After this operation, 23.1 MB of additional disk space will be used.
# Get:1 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.9-minimal amd64 3.9.23-1+jammy1 [837 kB]
# Get:2 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.9-minimal amd64 3.9.23-1+jammy1 [2,075 kB]
# Get:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.9-stdlib amd64 3.9.23-1+jammy1 [1,842 kB]
# Get:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.9 amd64 3.9.23-1+jammy1 [93.1 kB]
# Get:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.9-lib2to3 all 3.9.23-1+jammy1 [127 kB]
# Get:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.9-distutils all 3.9.23-1+jammy1 [193 kB]
# Get:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.9-venv amd64 3.9.23-1+jammy1 [2,650 kB]
# Fetched 7,816 kB in 21s (371 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 7.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libpython3.9-minimal:amd64.
# (Reading database ... 126284 files and directories currently installed.)
# Preparing to unpack .../0-libpython3.9-minimal_3.9.23-1+jammy1_amd64.deb ...
# Unpacking libpython3.9-minimal:amd64 (3.9.23-1+jammy1) ...
# Selecting previously unselected package python3.9-minimal.
# Preparing to unpack .../1-python3.9-minimal_3.9.23-1+jammy1_amd64.deb ...
# Unpacking python3.9-minimal (3.9.23-1+jammy1) ...
# Selecting previously unselected package libpython3.9-stdlib:amd64.
# Preparing to unpack .../2-libpython3.9-stdlib_3.9.23-1+jammy1_amd64.deb ...
# Unpacking libpython3.9-stdlib:amd64 (3.9.23-1+jammy1) ...
# Selecting previously unselected package python3.9.
# Preparing to unpack .../3-python3.9_3.9.23-1+jammy1_amd64.deb ...
# Unpacking python3.9 (3.9.23-1+jammy1) ...
# Selecting previously unselected package python3.9-lib2to3.
# Preparing to unpack .../4-python3.9-lib2to3_3.9.23-1+jammy1_all.deb ...
# Unpacking python3.9-lib2to3 (3.9.23-1+jammy1) ...
# Selecting previously unselected package python3.9-distutils.
# Preparing to unpack .../5-python3.9-distutils_3.9.23-1+jammy1_all.deb ...
# Unpacking python3.9-distutils (3.9.23-1+jammy1) ...
# Selecting previously unselected package python3.9-venv.
# Preparing to unpack .../6-python3.9-venv_3.9.23-1+jammy1_amd64.deb ...
# Unpacking python3.9-venv (3.9.23-1+jammy1) ...
# Setting up libpython3.9-minimal:amd64 (3.9.23-1+jammy1) ...
# Setting up python3.9-lib2to3 (3.9.23-1+jammy1) ...
# Setting up python3.9-distutils (3.9.23-1+jammy1) ...
# Setting up python3.9-minimal (3.9.23-1+jammy1) ...
# Setting up libpython3.9-stdlib:amd64 (3.9.23-1+jammy1) ...
# Setting up python3.9 (3.9.23-1+jammy1) ...
# Setting up python3.9-venv (3.9.23-1+jammy1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Requirement already satisfied: pip in ./myenv/lib/python3.9/site-packages (23.0.1)
# Collecting pip
#   Downloading pip-25.1.1-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 35.7 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0.1
#     Uninstalling pip-23.0.1:
#       Successfully uninstalled pip-23.0.1
# Successfully installed pip-25.1.1
# Collecting numpy==1.20.3
#   Downloading numpy-1.20.3-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (2.0 kB)
# Collecting scipy==1.6.3
#   Downloading scipy-1.6.3-cp39-cp39-manylinux1_x86_64.whl.metadata (2.1 kB)
# Collecting tensorboard==2.7.0
#   Downloading tensorboard-2.7.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting absl-py>=0.4 (from tensorboard==2.7.0)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting grpcio>=1.24.3 (from tensorboard==2.7.0)
#   Downloading grpcio-1.74.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard==2.7.0)
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard==2.7.0)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard==2.7.0)
#   Downloading markdown-3.8.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting protobuf>=3.6.0 (from tensorboard==2.7.0)
#   Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting requests<3,>=2.21.0 (from tensorboard==2.7.0)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: setuptools>=41.0.0 in ./myenv/lib/python3.9/site-packages (from tensorboard==2.7.0) (58.1.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard==2.7.0)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard==2.7.0)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Collecting werkzeug>=0.11.15 (from tensorboard==2.7.0)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting wheel>=0.26 (from tensorboard==2.7.0)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard==2.7.0)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard==2.7.0)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard==2.7.0)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.7.0)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.21.0->tensorboard==2.7.0)
#   Downloading charset_normalizer-3.4.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorboard==2.7.0)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorboard==2.7.0)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorboard==2.7.0)
#   Downloading certifi-2025.7.14-py3-none-any.whl.metadata (2.4 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard==2.7.0)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting importlib-metadata>=4.4 (from markdown>=2.6.8->tensorboard==2.7.0)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting zipp>=3.20 (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard==2.7.0)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.7.0)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=0.11.15->tensorboard==2.7.0)
#   Downloading MarkupSafe-3.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Downloading numpy-1.20.3-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 118.8 MB/s eta 0:00:00
# Downloading scipy-1.6.3-cp39-cp39-manylinux1_x86_64.whl (27.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.3/27.3 MB 58.6 MB/s eta 0:00:00
# Downloading tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 116.7 MB/s eta 0:00:00
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 153.4 MB/s eta 0:00:00
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading certifi-2025.7.14-py3-none-any.whl (162 kB)
# Downloading grpcio-1.74.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 148.3 MB/s eta 0:00:00
# Downloading markdown-3.8.2-py3-none-any.whl (106 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl (321 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 49.8 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading MarkupSafe-3.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: tensorboard-plugin-wit, zipp, wheel, urllib3, tensorboard-data-server, pyasn1, protobuf, oauthlib, numpy, MarkupSafe, idna, grpcio, charset_normalizer, certifi, cachetools, absl-py, werkzeug, scipy, rsa, requests, pyasn1-modules, importlib-metadata, requests-oauthlib, markdown, google-auth, google-auth-oauthlib, tensorboard
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27/27 [tensorboard]
# Successfully installed MarkupSafe-3.0.2 absl-py-2.3.1 cachetools-5.5.2 certifi-2025.7.14 charset_normalizer-3.4.2 google-auth-2.40.3 google-auth-oauthlib-0.4.6 grpcio-1.74.0 idna-3.10 importlib-metadata-8.7.0 markdown-3.8.2 numpy-1.20.3 oauthlib-3.3.1 protobuf-6.31.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 requests-2.32.4 requests-oauthlib-2.0.0 rsa-4.9.1 scipy-1.6.3 tensorboard-2.7.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 urllib3-2.5.0 werkzeug-3.1.3 wheel-0.45.1 zipp-3.23.0
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.8.1+cu111
#   Downloading https://download.pytorch.org/whl/cu111/torch-1.8.1%2Bcu111-cp39-cp39-linux_x86_64.whl (1982.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB 22.5 MB/s eta 0:00:00
# Collecting typing-extensions (from torch==1.8.1+cu111)
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy in ./myenv/lib/python3.9/site-packages (from torch==1.8.1+cu111) (1.20.3)
# Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Installing collected packages: typing-extensions, torch
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [torch]
# Successfully installed torch-1.8.1+cu111 typing-extensions-4.14.1
# Collecting PyYAML
#   Downloading PyYAML-6.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Downloading PyYAML-6.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (737 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.4/737.4 kB 41.5 MB/s eta 0:00:00
# Installing collected packages: PyYAML
# Successfully installed PyYAML-6.0.2
# Collecting colorlog
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog
# Successfully installed colorlog-6.9.0
# Collecting protobuf==3.19.0
#   Downloading protobuf-3.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (806 bytes)
# Downloading protobuf-3.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.5 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.31.1
#     Uninstalling protobuf-6.31.1:
#       Successfully uninstalled protobuf-6.31.1
# Successfully installed protobuf-3.19.0
# Collecting six
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six
# Successfully installed six-1.17.0
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.19.5 in ./myenv/lib/python3.9/site-packages (from scikit-learn) (1.20.3)
# Requirement already satisfied: scipy>=1.6.0 in ./myenv/lib/python3.9/site-packages (from scikit-learn) (1.6.3)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 163.5 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [scikit-learn]
# Successfully installed joblib-1.5.1 scikit-learn-1.6.1 threadpoolctl-3.6.0
# Collecting pandas==1.2.4
#   Downloading pandas-1.2.4-cp39-cp39-manylinux1_x86_64.whl.metadata (4.7 kB)
# Collecting python-dateutil>=2.7.3 (from pandas==1.2.4)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2017.3 (from pandas==1.2.4)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numpy>=1.16.5 in ./myenv/lib/python3.9/site-packages (from pandas==1.2.4) (1.20.3)
# Requirement already satisfied: six>=1.5 in ./myenv/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas==1.2.4) (1.17.0)
# Downloading pandas-1.2.4-cp39-cp39-manylinux1_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 121.7 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Installing collected packages: pytz, python-dateutil, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]
# Successfully installed pandas-1.2.4 python-dateutil-2.9.0.post0 pytz-2025.2
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.1

# %%
# !git clone https://github.com/PiotrStachowicz/SequentialRecommendation.git
# Out:
# Cloning into 'SequentialRecommendation'...
# remote: Enumerating objects: 574, done.
# remote: Counting objects: 100% (229/229), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 574 (delta 154), reused 135 (delta 84), pack-reused 345 (from 1)
# Receiving objects: 100% (574/574), 4.82 MiB | 16.24 MiB/s, done.
# Resolving deltas: 100% (252/252), done.

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp -r "/content/drive/My Drive/Amazon_Sports_and_Outdoors" "/content/SequentialRecommendation/recbole/data/dataset/"
# Out:
# Mounted at /content/drive

# %%
# !./myenv/bin/python /content/SequentialRecommendation/run_recbole.py --gpu_id=0 --model=SASRecD --dataset='Amazon_Sports_and_Outdoors' --config_files='/content/SequentialRecommendation/configs/Amazon_Sports_and_Outdoors.yaml'
# Out:
# 30 Jul 17:15    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 212
# state = INFO
# reproducibility = True
# data_path = /content/SequentialRecommendation/recbole/data/dataset/Amazon_Sports_and_Outdoors
# show_progress = True
# save_dataset = False
# save_dataloaders = False
# benchmark_filename = None
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 40
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0001
# eval_step = 2
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'LS': 'valid_and_test'}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# metrics = ['Recall', 'NDCG']
# topk = [3, 5, 10, 20]
# valid_metric = Recall@20
# valid_metric_bigger = True
# eval_batch_size = 256
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'rating', 'timestamp'], 'item': ['item_id'], 'image': ['ent_id', 'ent_emb']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = ['image']
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [5,inf)
# item_inter_num_interval = [5,inf)
# alias_of_user_id = None
# alias_of_item_id = ['ent_id']
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = {'ent_id': 'ent_emb'}
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
#
# Other Hyper Parameters:
# neg_sampling = None
# multi_gpus = False
# repeatable = True
# n_layers = 3
# n_heads = 8
# hidden_size = 256
# attribute_hidden_size = [128]
# inner_size = 256
# hidden_dropout_prob = 0.5
# attn_dropout_prob = 0.3
# hidden_act = gelu
# layer_norm_eps = 1e-12
# initializer_range = 0.02
# selected_features = ['ent_emb']
# pooling_mode = sum
# loss_type = CE
# weight_sharing = not
# fusion_type = gate
# lamdas = [5]
# attribute_predictor = not
# MODEL_TYPE = ModelType.SEQUENTIAL
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# device = cuda
# train_neg_sample_args = {'strategy': 'none'}
# eval_neg_sample_args = {'strategy': 'full', 'distribution': 'uniform'}
#
#
# 30 Jul 17:20    INFO  Amazon_Sports_and_Outdoors
# The number of users: 425813
# Average actions of users: 8.514189360562877
# The number of items: 1587220
# Average actions of items: 22.46776812384576
# The number of inters: 3625444
# The sparsity of the dataset: 99.99946357975797%
# Remain Fields: ['user_id', 'item_id', 'rating', 'timestamp', 'ent_id', 'ent_emb']
# 30 Jul 17:21    INFO  [Training]: train_batch_size = [1024] negative sampling: [None]
# 30 Jul 17:21    INFO  [Evaluation]: eval_batch_size = [256] eval_args: [{'split': {'LS': 'valid_and_test'}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# 30 Jul 17:22    INFO  SASRecD(
#   (item_embedding): Embedding(1587220, 256, padding_idx=0)
#   (position_embedding): Embedding(50, 256)
#   (feature_embed_layer_list): ModuleList(
#     (0): Embedding(1587220, 128)
#   )
#   (trm_encoder): DIFTransformerEncoder(
#     (layer): ModuleList(
#       (0): DIFTransformerLayer(
#         (multi_head_attention): DIFMultiHeadAttention(
#           (query): Linear(in_features=256, out_features=256, bias=True)
#           (key): Linear(in_features=256, out_features=256, bias=True)
#           (value): Linear(in_features=256, out_features=256, bias=True)
#           (query_p): Linear(in_features=256, out_features=256, bias=True)
#           (key_p): Linear(in_features=256, out_features=256, bias=True)
#           (query_layers): ModuleList(
#             (0): Linear(in_features=128, out_features=128, bias=True)
#           )
#           (key_layers): ModuleList(
#             (0): Linear(in_features=128, out_features=128, bias=True)
#           )
#           (fusion_layer): VanillaAttention(
#             (projection): Sequential(
#               (0): Linear(in_features=50, out_features=50, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=50, out_features=1, bias=True)
#             )
#           )
#           (attn_dropout): Dropout(p=0.3, inplace=False)
#           (dense): Linear(in_features=256, out_features=256, bias=True)
#           (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=256, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=256, bias=True)
#           (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#       (1): DIFTransformerLayer(
#         (multi_head_attention): DIFMultiHeadAttention(
#           (query): Linear(in_features=256, out_features=256, bias=True)
#           (key): Linear(in_features=256, out_features=256, bias=True)
#           (value): Linear(in_features=256, out_features=256, bias=True)
#           (query_p): Linear(in_features=256, out_features=256, bias=True)
#           (key_p): Linear(in_features=256, out_features=256, bias=True)
#           (query_layers): ModuleList(
#             (0): Linear(in_features=128, out_features=128, bias=True)
#           )
#           (key_layers): ModuleList(
#             (0): Linear(in_features=128, out_features=128, bias=True)
#           )
#           (fusion_layer): VanillaAttention(
#             (projection): Sequential(
#               (0): Linear(in_features=50, out_features=50, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=50, out_features=1, bias=True)
#             )
#           )
#           (attn_dropout): Dropout(p=0.3, inplace=False)
#           (dense): Linear(in_features=256, out_features=256, bias=True)
#           (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=256, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=256, bias=True)
#           (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#       (2): DIFTransformerLayer(
#         (multi_head_attention): DIFMultiHeadAttention(
#           (query): Linear(in_features=256, out_features=256, bias=True)
#           (key): Linear(in_features=256, out_features=256, bias=True)
#           (value): Linear(in_features=256, out_features=256, bias=True)
#           (query_p): Linear(in_features=256, out_features=256, bias=True)
#           (key_p): Linear(in_features=256, out_features=256, bias=True)
#           (query_layers): ModuleList(
#             (0): Linear(in_features=128, out_features=128, bias=True)
#           )
#           (key_layers): ModuleList(
#             (0): Linear(in_features=128, out_features=128, bias=True)
#           )
#           (fusion_layer): VanillaAttention(
#             (projection): Sequential(
#               (0): Linear(in_features=50, out_features=50, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=50, out_features=1, bias=True)
#             )
#           )
#           (attn_dropout): Dropout(p=0.3, inplace=False)
#           (dense): Linear(in_features=256, out_features=256, bias=True)
#           (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=256, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=256, bias=True)
#           (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#     )
#   )
#   (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (loss_fct): CrossEntropyLoss()
#   (attribute_loss_fct): BCEWithLogitsLoss()
# )
# Trainable parameters: 408030587
# Train     0: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 17:29    INFO  epoch 0 training [time: 459.34s, train loss: 26322.9290]
# Train     1: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 17:37    INFO  epoch 1 training [time: 459.07s, train loss: 24856.7853]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:29<00:00, 18.57it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 17:38    INFO  epoch 1 evaluating [time: 90.64s, valid_score: 0.031600]
# 30 Jul 17:38    INFO  valid result:
# recall@3 : 0.0141    recall@5 : 0.0171    recall@10 : 0.0229    recall@20 : 0.0316    ndcg@3 : 0.012    ndcg@5 : 0.0132    ndcg@10 : 0.0151    ndcg@20 : 0.0173
# 30 Jul 17:39    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-00.pth
# Train     2: 100%|████████████████████| 2293/2293 [07:39<00:00,  5.00it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 17:46    INFO  epoch 2 training [time: 459.04s, train loss: 23701.8180]
# Train     3: 100%|████████████████████| 2293/2293 [07:39<00:00,  5.00it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 17:54    INFO  epoch 3 training [time: 459.01s, train loss: 22691.4938]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:29<00:00, 18.62it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 17:55    INFO  epoch 3 evaluating [time: 90.38s, valid_score: 0.050500]
# 30 Jul 17:55    INFO  valid result:
# recall@3 : 0.0227    recall@5 : 0.0282    recall@10 : 0.0376    recall@20 : 0.0505    ndcg@3 : 0.0186    ndcg@5 : 0.0208    ndcg@10 : 0.0239    ndcg@20 : 0.0271
# 30 Jul 17:56    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-00.pth
# Train     4: 100%|████████████████████| 2293/2293 [07:38<00:00,  5.00it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:03    INFO  epoch 4 training [time: 458.94s, train loss: 21899.9793]
# Train     5: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:11    INFO  epoch 5 training [time: 459.15s, train loss: 21244.4943]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:27<00:00, 18.92it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:12    INFO  epoch 5 evaluating [time: 88.94s, valid_score: 0.059000]
# 30 Jul 18:12    INFO  valid result:
# recall@3 : 0.0264    recall@5 : 0.0332    recall@10 : 0.0443    recall@20 : 0.059    ndcg@3 : 0.0208    ndcg@5 : 0.0236    ndcg@10 : 0.0272    ndcg@20 : 0.0309
# 30 Jul 18:13    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-00.pth
# Train     6: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:20    INFO  epoch 6 training [time: 459.18s, train loss: 20713.8925]
# Train     7: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:28    INFO  epoch 7 training [time: 459.11s, train loss: 20292.6336]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:29<00:00, 18.59it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:30    INFO  epoch 7 evaluating [time: 90.53s, valid_score: 0.063200]
# 30 Jul 18:30    INFO  valid result:
# recall@3 : 0.0279    recall@5 : 0.0352    recall@10 : 0.0474    recall@20 : 0.0632    ndcg@3 : 0.0217    ndcg@5 : 0.0247    ndcg@10 : 0.0286    ndcg@20 : 0.0326
# 30 Jul 18:30    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-00.pth
# Train     8: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:38    INFO  epoch 8 training [time: 459.23s, train loss: 19960.1719]
# Train     9: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:45    INFO  epoch 9 training [time: 459.22s, train loss: 19694.0889]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:30<00:00, 18.43it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:47    INFO  epoch 9 evaluating [time: 91.29s, valid_score: 0.065100]
# 30 Jul 18:47    INFO  valid result:
# recall@3 : 0.0283    recall@5 : 0.036    recall@10 : 0.0488    recall@20 : 0.0651    ndcg@3 : 0.0219    ndcg@5 : 0.0251    ndcg@10 : 0.0292    ndcg@20 : 0.0333
# 30 Jul 18:47    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-00.pth
# Train    10: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:55    INFO  epoch 10 training [time: 459.20s, train loss: 19470.4321]
# Train    11: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:02    INFO  epoch 11 training [time: 459.16s, train loss: 19280.0357]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:29<00:00, 18.64it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:04    INFO  epoch 11 evaluating [time: 90.29s, valid_score: 0.065900]
# 30 Jul 19:04    INFO  valid result:
# recall@3 : 0.0284    recall@5 : 0.0363    recall@10 : 0.049    recall@20 : 0.0659    ndcg@3 : 0.0219    ndcg@5 : 0.0252    ndcg@10 : 0.0293    ndcg@20 : 0.0335
# 30 Jul 19:04    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-00.pth
# Train    12: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:12    INFO  epoch 12 training [time: 459.44s, train loss: 19115.8804]
# Train    13: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:19    INFO  epoch 13 training [time: 459.21s, train loss: 18970.6674]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:29<00:00, 18.67it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:21    INFO  epoch 13 evaluating [time: 90.13s, valid_score: 0.066600]
# 30 Jul 19:21    INFO  valid result:
# recall@3 : 0.0285    recall@5 : 0.0366    recall@10 : 0.0496    recall@20 : 0.0666    ndcg@3 : 0.022    ndcg@5 : 0.0253    ndcg@10 : 0.0295    ndcg@20 : 0.0338
# 30 Jul 19:21    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-00.pth
# Train    14: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:29    INFO  epoch 14 training [time: 459.58s, train loss: 18836.5493]
# Train    15: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:37    INFO  epoch 15 training [time: 459.46s, train loss: 18716.6252]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:29<00:00, 18.62it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:38    INFO  epoch 15 evaluating [time: 90.36s, valid_score: 0.067100]
# 30 Jul 19:38    INFO  valid result:
# recall@3 : 0.0282    recall@5 : 0.0364    recall@10 : 0.0499    recall@20 : 0.0671    ndcg@3 : 0.0219    ndcg@5 : 0.0252    ndcg@10 : 0.0296    ndcg@20 : 0.0339
# 30 Jul 19:38    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-00.pth
# Train    16: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:46    INFO  epoch 16 training [time: 459.61s, train loss: 18605.5460]
# Train    17: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:54    INFO  epoch 17 training [time: 459.58s, train loss: 18500.6138]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:27<00:00, 19.07it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:55    INFO  epoch 17 evaluating [time: 88.26s, valid_score: 0.066700]
# 30 Jul 19:55    INFO  valid result:
# recall@3 : 0.0281    recall@5 : 0.0362    recall@10 : 0.0495    recall@20 : 0.0667    ndcg@3 : 0.0218    ndcg@5 : 0.0251    ndcg@10 : 0.0294    ndcg@20 : 0.0337
# Train    18: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:03    INFO  epoch 18 training [time: 459.50s, train loss: 18404.7752]
# Train    19: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:10    INFO  epoch 19 training [time: 459.26s, train loss: 18315.0936]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:26<00:00, 19.34it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:12    INFO  epoch 19 evaluating [time: 87.03s, valid_score: 0.066500]
# 30 Jul 20:12    INFO  valid result:
# recall@3 : 0.0278    recall@5 : 0.0361    recall@10 : 0.0492    recall@20 : 0.0665    ndcg@3 : 0.0216    ndcg@5 : 0.025    ndcg@10 : 0.0293    ndcg@20 : 0.0336
# Train    20: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:20    INFO  epoch 20 training [time: 459.40s, train loss: 18223.0443]
# Train    21: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:27    INFO  epoch 21 training [time: 459.36s, train loss: 18142.5578]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:28<00:00, 18.81it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:29    INFO  epoch 21 evaluating [time: 89.46s, valid_score: 0.065900]
# 30 Jul 20:29    INFO  valid result:
# recall@3 : 0.0277    recall@5 : 0.0358    recall@10 : 0.0489    recall@20 : 0.0659    ndcg@3 : 0.0216    ndcg@5 : 0.0249    ndcg@10 : 0.0291    ndcg@20 : 0.0334
# Train    22: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:36    INFO  epoch 22 training [time: 459.52s, train loss: 18062.8536]
# Train    23: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:44    INFO  epoch 23 training [time: 459.39s, train loss: 17985.1784]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:28<00:00, 18.71it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:46    INFO  epoch 23 evaluating [time: 89.97s, valid_score: 0.065100]
# 30 Jul 20:46    INFO  valid result:
# recall@3 : 0.0274    recall@5 : 0.0352    recall@10 : 0.0482    recall@20 : 0.0651    ndcg@3 : 0.0214    ndcg@5 : 0.0246    ndcg@10 : 0.0288    ndcg@20 : 0.033
# Train    24: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:53    INFO  epoch 24 training [time: 459.46s, train loss: 17910.6337]
# Train    25: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:01    INFO  epoch 25 training [time: 459.39s, train loss: 17836.9419]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:29<00:00, 18.59it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:02    INFO  epoch 25 evaluating [time: 90.52s, valid_score: 0.065100]
# 30 Jul 21:02    INFO  valid result:
# recall@3 : 0.0273    recall@5 : 0.0352    recall@10 : 0.0482    recall@20 : 0.0651    ndcg@3 : 0.0214    ndcg@5 : 0.0246    ndcg@10 : 0.0288    ndcg@20 : 0.033
# Train    26: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:10    INFO  epoch 26 training [time: 459.11s, train loss: 17763.9599]
# Train    27: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:18    INFO  epoch 27 training [time: 459.28s, train loss: 17693.2718]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:28<00:00, 18.70it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:19    INFO  epoch 27 evaluating [time: 89.99s, valid_score: 0.064100]
# 30 Jul 21:19    INFO  valid result:
# recall@3 : 0.027    recall@5 : 0.0347    recall@10 : 0.0475    recall@20 : 0.0641    ndcg@3 : 0.0211    ndcg@5 : 0.0243    ndcg@10 : 0.0285    ndcg@20 : 0.0326
# Train    28: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:27    INFO  epoch 28 training [time: 459.71s, train loss: 17620.3843]
# Train    29: 100%|████████████████████| 2293/2293 [07:40<00:00,  4.98it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:34    INFO  epoch 29 training [time: 460.17s, train loss: 17555.3722]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:31<00:00, 18.28it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:36    INFO  epoch 29 evaluating [time: 92.04s, valid_score: 0.063500]
# 30 Jul 21:36    INFO  valid result:
# recall@3 : 0.0268    recall@5 : 0.0344    recall@10 : 0.047    recall@20 : 0.0635    ndcg@3 : 0.021    ndcg@5 : 0.0242    ndcg@10 : 0.0282    ndcg@20 : 0.0324
# Train    30: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:44    INFO  epoch 30 training [time: 459.36s, train loss: 17484.5752]
# Train    31: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:51    INFO  epoch 31 training [time: 459.77s, train loss: 17417.0031]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:29<00:00, 18.60it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:53    INFO  epoch 31 evaluating [time: 90.44s, valid_score: 0.063200]
# 30 Jul 21:53    INFO  valid result:
# recall@3 : 0.0266    recall@5 : 0.0342    recall@10 : 0.047    recall@20 : 0.0632    ndcg@3 : 0.0209    ndcg@5 : 0.0241    ndcg@10 : 0.0282    ndcg@20 : 0.0323
# Train    32: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:01    INFO  epoch 32 training [time: 459.29s, train loss: 17346.0595]
# Train    33: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:08    INFO  epoch 33 training [time: 459.15s, train loss: 17285.0920]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:29<00:00, 18.57it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:10    INFO  epoch 33 evaluating [time: 90.63s, valid_score: 0.062400]
# 30 Jul 22:10    INFO  valid result:
# recall@3 : 0.0264    recall@5 : 0.0338    recall@10 : 0.0462    recall@20 : 0.0624    ndcg@3 : 0.0209    ndcg@5 : 0.0239    ndcg@10 : 0.0279    ndcg@20 : 0.032
# Train    34: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:17    INFO  epoch 34 training [time: 459.06s, train loss: 17217.0590]
# Train    35: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:25    INFO  epoch 35 training [time: 459.16s, train loss: 17149.8509]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:27<00:00, 18.94it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:26    INFO  epoch 35 evaluating [time: 88.88s, valid_score: 0.061100]
# 30 Jul 22:26    INFO  valid result:
# recall@3 : 0.0259    recall@5 : 0.0334    recall@10 : 0.0455    recall@20 : 0.0611    ndcg@3 : 0.0205    ndcg@5 : 0.0236    ndcg@10 : 0.0275    ndcg@20 : 0.0314
# Train    36: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:34    INFO  epoch 36 training [time: 459.63s, train loss: 17086.5741]
# Train    37: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:42    INFO  epoch 37 training [time: 459.51s, train loss: 17022.6355]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:26<00:00, 19.24it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:43    INFO  epoch 37 evaluating [time: 87.45s, valid_score: 0.061200]
# 30 Jul 22:43    INFO  valid result:
# recall@3 : 0.0258    recall@5 : 0.0332    recall@10 : 0.0454    recall@20 : 0.0612    ndcg@3 : 0.0205    ndcg@5 : 0.0236    ndcg@10 : 0.0275    ndcg@20 : 0.0315
# 30 Jul 22:43    INFO  Finished training, best eval result in epoch 15
# 30 Jul 22:43    INFO  Loading model structure and parameters from saved/SASRecD-Jul-30-2025_17-22-00.pth
# Evaluate   : 100%|████████████████████| 1664/1664 [01:27<00:00, 19.11it/s, GPU RAM: 37.69 G/39.56 G]
# 30 Jul 22:45    INFO  best valid : {'recall@3': 0.0282, 'recall@5': 0.0364, 'recall@10': 0.0499, 'recall@20': 0.0671, 'ndcg@3': 0.0219, 'ndcg@5': 0.0252, 'ndcg@10': 0.0296, 'ndcg@20': 0.0339}
# 30 Jul 22:45    INFO  test result: {'recall@3': 0.0443, 'recall@5': 0.0505, 'recall@10': 0.0606, 'recall@20': 0.074, 'ndcg@3': 0.0391, 'ndcg@5': 0.0416, 'ndcg@10': 0.0449, 'ndcg@20': 0.0483}
# 19765.85895037651

# %%
# !cp /content/saved/image_2023_without_side_task.pth /content/drive/MyDrive/

# %%
from google.colab import drive

drive.flush_and_unmount()
