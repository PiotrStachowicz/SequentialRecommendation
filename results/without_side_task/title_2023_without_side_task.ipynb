# %%
# !sudo apt update
# !sudo apt install python3.9 python3.9-venv
# !python3.9 -m venv myenv
# !source myenv/bin/activate
# !./myenv/bin/pip install --upgrade pip
# !./myenv/bin/pip install numpy==1.20.3 scipy==1.6.3 tensorboard==2.7.0
# !./myenv/bin/pip install torch==1.8.1+cu111 -f https://download.pytorch.org/whl/torch_stable.html
# !./myenv/bin/pip install PyYAML
# !./myenv/bin/pip install colorlog
# !./myenv/bin/pip install protobuf==3.19.0
# !./myenv/bin/pip install six
# !./myenv/bin/pip install colorama
# !./myenv/bin/pip install scikit-learn
# !./myenv/bin/pip install pandas==1.2.4
# !./myenv/bin/pip install tqdm
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 36 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.9 is already the newest version (3.9.23-1+jammy1).
# python3.9-venv is already the newest version (3.9.23-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.
# Requirement already satisfied: pip in ./myenv/lib/python3.9/site-packages (25.1.1)
# Collecting numpy==1.20.3
#   Using cached numpy-1.20.3-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (2.0 kB)
# Collecting scipy==1.6.3
#   Using cached scipy-1.6.3-cp39-cp39-manylinux1_x86_64.whl.metadata (2.1 kB)
# Collecting tensorboard==2.7.0
#   Using cached tensorboard-2.7.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting absl-py>=0.4 (from tensorboard==2.7.0)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting grpcio>=1.24.3 (from tensorboard==2.7.0)
#   Using cached grpcio-1.74.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard==2.7.0)
#   Using cached google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard==2.7.0)
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard==2.7.0)
#   Using cached markdown-3.8.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: protobuf>=3.6.0 in ./myenv/lib/python3.9/site-packages (from tensorboard==2.7.0) (3.19.0)
# Collecting requests<3,>=2.21.0 (from tensorboard==2.7.0)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: setuptools>=41.0.0 in ./myenv/lib/python3.9/site-packages (from tensorboard==2.7.0) (58.1.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard==2.7.0)
#   Using cached tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard==2.7.0)
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Collecting werkzeug>=0.11.15 (from tensorboard==2.7.0)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting wheel>=0.26 (from tensorboard==2.7.0)
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard==2.7.0)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard==2.7.0)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard==2.7.0)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.7.0)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.21.0->tensorboard==2.7.0)
#   Using cached charset_normalizer-3.4.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorboard==2.7.0)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorboard==2.7.0)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorboard==2.7.0)
#   Using cached certifi-2025.7.14-py3-none-any.whl.metadata (2.4 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard==2.7.0)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting importlib-metadata>=4.4 (from markdown>=2.6.8->tensorboard==2.7.0)
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting zipp>=3.20 (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard==2.7.0)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.7.0)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=0.11.15->tensorboard==2.7.0)
#   Using cached MarkupSafe-3.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Using cached numpy-1.20.3-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.4 MB)
# Downloading scipy-1.6.3-cp39-cp39-manylinux1_x86_64.whl (27.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.3/27.3 MB 117.9 MB/s eta 0:00:00
# Downloading tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 104.7 MB/s eta 0:00:00
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 141.7 MB/s eta 0:00:00
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading certifi-2025.7.14-py3-none-any.whl (162 kB)
# Downloading grpcio-1.74.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 122.6 MB/s eta 0:00:00
# Downloading markdown-3.8.2-py3-none-any.whl (106 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 44.4 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading MarkupSafe-3.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: tensorboard-plugin-wit, zipp, wheel, urllib3, tensorboard-data-server, pyasn1, oauthlib, numpy, MarkupSafe, idna, grpcio, charset_normalizer, certifi, cachetools, absl-py, werkzeug, scipy, rsa, requests, pyasn1-modules, importlib-metadata, requests-oauthlib, markdown, google-auth, google-auth-oauthlib, tensorboard
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26/26 [tensorboard]
# Successfully installed MarkupSafe-3.0.2 absl-py-2.3.1 cachetools-5.5.2 certifi-2025.7.14 charset_normalizer-3.4.2 google-auth-2.40.3 google-auth-oauthlib-0.4.6 grpcio-1.74.0 idna-3.10 importlib-metadata-8.7.0 markdown-3.8.2 numpy-1.20.3 oauthlib-3.3.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 requests-2.32.4 requests-oauthlib-2.0.0 rsa-4.9.1 scipy-1.6.3 tensorboard-2.7.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 urllib3-2.5.0 werkzeug-3.1.3 wheel-0.45.1 zipp-3.23.0
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch==1.8.1+cu111 in ./myenv/lib/python3.9/site-packages (1.8.1+cu111)
# Requirement already satisfied: typing-extensions in ./myenv/lib/python3.9/site-packages (from torch==1.8.1+cu111) (4.14.1)
# Requirement already satisfied: numpy in ./myenv/lib/python3.9/site-packages (from torch==1.8.1+cu111) (1.20.3)
# Requirement already satisfied: PyYAML in ./myenv/lib/python3.9/site-packages (6.0.2)
# Requirement already satisfied: colorlog in ./myenv/lib/python3.9/site-packages (6.9.0)
# Requirement already satisfied: protobuf==3.19.0 in ./myenv/lib/python3.9/site-packages (3.19.0)
# Requirement already satisfied: six in ./myenv/lib/python3.9/site-packages (1.17.0)
# Requirement already satisfied: colorama in ./myenv/lib/python3.9/site-packages (0.4.6)
# Requirement already satisfied: scikit-learn in ./myenv/lib/python3.9/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in ./myenv/lib/python3.9/site-packages (from scikit-learn) (1.20.3)
# Requirement already satisfied: scipy>=1.6.0 in ./myenv/lib/python3.9/site-packages (from scikit-learn) (1.6.3)
# Requirement already satisfied: joblib>=1.2.0 in ./myenv/lib/python3.9/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./myenv/lib/python3.9/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pandas==1.2.4 in ./myenv/lib/python3.9/site-packages (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in ./myenv/lib/python3.9/site-packages (from pandas==1.2.4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in ./myenv/lib/python3.9/site-packages (from pandas==1.2.4) (2025.2)
# Requirement already satisfied: numpy>=1.16.5 in ./myenv/lib/python3.9/site-packages (from pandas==1.2.4) (1.20.3)
# Requirement already satisfied: six>=1.5 in ./myenv/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas==1.2.4) (1.17.0)
# Requirement already satisfied: tqdm in ./myenv/lib/python3.9/site-packages (4.67.1)

# %%
# !git clone https://github.com/PiotrStachowicz/SequentialRecommendation.git
# Out:
# Cloning into 'SequentialRecommendation'...
# remote: Enumerating objects: 574, done.
# remote: Counting objects: 100% (229/229), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 574 (delta 154), reused 135 (delta 84), pack-reused 345 (from 1)
# Receiving objects: 100% (574/574), 4.82 MiB | 19.59 MiB/s, done.
# Resolving deltas: 100% (252/252), done.

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp -r "/content/drive/My Drive/Amazon_Sports_and_Outdoors" "/content/SequentialRecommendation/recbole/data/dataset/"
# Out:
# Mounted at /content/drive

# %%
# !./myenv/bin/python /content/SequentialRecommendation/run_recbole.py --gpu_id=0 --model=SASRecD --dataset='Amazon_Sports_and_Outdoors' --config_files='/content/SequentialRecommendation/configs/Amazon_Sports_and_Outdoors.yaml'
# Out:
# 30 Jul 17:15    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 212
# state = INFO
# reproducibility = True
# data_path = /content/SequentialRecommendation/recbole/data/dataset/Amazon_Sports_and_Outdoors
# show_progress = True
# save_dataset = False
# save_dataloaders = False
# benchmark_filename = None
#
# Training Hyper Parameters:
# checkpoint_dir = saved
# epochs = 40
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0001
# eval_step = 2
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'LS': 'valid_and_test'}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# metrics = ['Recall', 'NDCG']
# topk = [3, 5, 10, 20]
# valid_metric = Recall@20
# valid_metric_bigger = True
# eval_batch_size = 256
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'rating', 'timestamp'], 'item': ['item_id'], 'title': ['ent_id', 'ent_emb']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = ['title']
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [5,inf)
# item_inter_num_interval = [5,inf)
# alias_of_user_id = None
# alias_of_item_id = ['ent_id']
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = {'ent_id': 'ent_emb'}
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
#
# Other Hyper Parameters:
# neg_sampling = None
# multi_gpus = False
# repeatable = True
# n_layers = 3
# n_heads = 8
# hidden_size = 256
# attribute_hidden_size = [128]
# inner_size = 256
# hidden_dropout_prob = 0.5
# attn_dropout_prob = 0.3
# hidden_act = gelu
# layer_norm_eps = 1e-12
# initializer_range = 0.02
# selected_features = ['ent_emb']
# pooling_mode = sum
# loss_type = CE
# weight_sharing = not
# fusion_type = gate
# lamdas = [5]
# attribute_predictor = not
# MODEL_TYPE = ModelType.SEQUENTIAL
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# device = cuda
# train_neg_sample_args = {'strategy': 'none'}
# eval_neg_sample_args = {'strategy': 'full', 'distribution': 'uniform'}
#
#
# 30 Jul 17:20    INFO  Amazon_Sports_and_Outdoors
# The number of users: 425813
# Average actions of users: 8.514189360562877
# The number of items: 1587220
# Average actions of items: 22.46776812384576
# The number of inters: 3625444
# The sparsity of the dataset: 99.99946357975797%
# Remain Fields: ['user_id', 'item_id', 'rating', 'timestamp', 'ent_id', 'ent_emb']
# 30 Jul 17:22    INFO  [Training]: train_batch_size = [1024] negative sampling: [None]
# 30 Jul 17:22    INFO  [Evaluation]: eval_batch_size = [256] eval_args: [{'split': {'LS': 'valid_and_test'}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# 30 Jul 17:22    INFO  SASRecD(
#   (item_embedding): Embedding(1587220, 256, padding_idx=0)
#   (position_embedding): Embedding(50, 256)
#   (feature_embed_layer_list): ModuleList(
#     (0): Embedding(1587220, 128)
#   )
#   (trm_encoder): DIFTransformerEncoder(
#     (layer): ModuleList(
#       (0): DIFTransformerLayer(
#         (multi_head_attention): DIFMultiHeadAttention(
#           (query): Linear(in_features=256, out_features=256, bias=True)
#           (key): Linear(in_features=256, out_features=256, bias=True)
#           (value): Linear(in_features=256, out_features=256, bias=True)
#           (query_p): Linear(in_features=256, out_features=256, bias=True)
#           (key_p): Linear(in_features=256, out_features=256, bias=True)
#           (query_layers): ModuleList(
#             (0): Linear(in_features=128, out_features=128, bias=True)
#           )
#           (key_layers): ModuleList(
#             (0): Linear(in_features=128, out_features=128, bias=True)
#           )
#           (fusion_layer): VanillaAttention(
#             (projection): Sequential(
#               (0): Linear(in_features=50, out_features=50, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=50, out_features=1, bias=True)
#             )
#           )
#           (attn_dropout): Dropout(p=0.3, inplace=False)
#           (dense): Linear(in_features=256, out_features=256, bias=True)
#           (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=256, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=256, bias=True)
#           (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#       (1): DIFTransformerLayer(
#         (multi_head_attention): DIFMultiHeadAttention(
#           (query): Linear(in_features=256, out_features=256, bias=True)
#           (key): Linear(in_features=256, out_features=256, bias=True)
#           (value): Linear(in_features=256, out_features=256, bias=True)
#           (query_p): Linear(in_features=256, out_features=256, bias=True)
#           (key_p): Linear(in_features=256, out_features=256, bias=True)
#           (query_layers): ModuleList(
#             (0): Linear(in_features=128, out_features=128, bias=True)
#           )
#           (key_layers): ModuleList(
#             (0): Linear(in_features=128, out_features=128, bias=True)
#           )
#           (fusion_layer): VanillaAttention(
#             (projection): Sequential(
#               (0): Linear(in_features=50, out_features=50, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=50, out_features=1, bias=True)
#             )
#           )
#           (attn_dropout): Dropout(p=0.3, inplace=False)
#           (dense): Linear(in_features=256, out_features=256, bias=True)
#           (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=256, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=256, bias=True)
#           (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#       (2): DIFTransformerLayer(
#         (multi_head_attention): DIFMultiHeadAttention(
#           (query): Linear(in_features=256, out_features=256, bias=True)
#           (key): Linear(in_features=256, out_features=256, bias=True)
#           (value): Linear(in_features=256, out_features=256, bias=True)
#           (query_p): Linear(in_features=256, out_features=256, bias=True)
#           (key_p): Linear(in_features=256, out_features=256, bias=True)
#           (query_layers): ModuleList(
#             (0): Linear(in_features=128, out_features=128, bias=True)
#           )
#           (key_layers): ModuleList(
#             (0): Linear(in_features=128, out_features=128, bias=True)
#           )
#           (fusion_layer): VanillaAttention(
#             (projection): Sequential(
#               (0): Linear(in_features=50, out_features=50, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=50, out_features=1, bias=True)
#             )
#           )
#           (attn_dropout): Dropout(p=0.3, inplace=False)
#           (dense): Linear(in_features=256, out_features=256, bias=True)
#           (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.5, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=256, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=256, bias=True)
#           (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.5, inplace=False)
#         )
#       )
#     )
#   )
#   (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (loss_fct): CrossEntropyLoss()
#   (attribute_loss_fct): BCEWithLogitsLoss()
# )
# Trainable parameters: 408030587
# Train     0: 100%|████████████████████| 2293/2293 [07:40<00:00,  4.98it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 17:29    INFO  epoch 0 training [time: 460.18s, train loss: 26322.9075]
# Train     1: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 17:37    INFO  epoch 1 training [time: 459.78s, train loss: 24856.7336]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:30<00:00, 18.47it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 17:39    INFO  epoch 1 evaluating [time: 91.14s, valid_score: 0.031600]
# 30 Jul 17:39    INFO  valid result:
# recall@3 : 0.014    recall@5 : 0.0171    recall@10 : 0.0229    recall@20 : 0.0316    ndcg@3 : 0.0119    ndcg@5 : 0.0132    ndcg@10 : 0.0151    ndcg@20 : 0.0173
# 30 Jul 17:39    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-13.pth
# Train     2: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 17:47    INFO  epoch 2 training [time: 459.89s, train loss: 23701.9775]
# Train     3: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 17:54    INFO  epoch 3 training [time: 459.89s, train loss: 22691.6137]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:29<00:00, 18.51it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 17:56    INFO  epoch 3 evaluating [time: 90.92s, valid_score: 0.050500]
# 30 Jul 17:56    INFO  valid result:
# recall@3 : 0.0228    recall@5 : 0.0281    recall@10 : 0.0376    recall@20 : 0.0505    ndcg@3 : 0.0186    ndcg@5 : 0.0208    ndcg@10 : 0.0239    ndcg@20 : 0.0271
# 30 Jul 17:56    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-13.pth
# Train     4: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:04    INFO  epoch 4 training [time: 459.88s, train loss: 21899.8974]
# Train     5: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:11    INFO  epoch 5 training [time: 459.91s, train loss: 21244.6976]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:29<00:00, 18.49it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:13    INFO  epoch 5 evaluating [time: 91.00s, valid_score: 0.059000]
# 30 Jul 18:13    INFO  valid result:
# recall@3 : 0.0264    recall@5 : 0.0332    recall@10 : 0.0443    recall@20 : 0.059    ndcg@3 : 0.0208    ndcg@5 : 0.0236    ndcg@10 : 0.0272    ndcg@20 : 0.0309
# 30 Jul 18:13    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-13.pth
# Train     6: 100%|████████████████████| 2293/2293 [07:40<00:00,  4.98it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:21    INFO  epoch 6 training [time: 460.07s, train loss: 20714.3413]
# Train     7: 100%|████████████████████| 2293/2293 [07:40<00:00,  4.98it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:29    INFO  epoch 7 training [time: 460.01s, train loss: 20293.0645]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:28<00:00, 18.71it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:30    INFO  epoch 7 evaluating [time: 89.96s, valid_score: 0.063100]
# 30 Jul 18:30    INFO  valid result:
# recall@3 : 0.0279    recall@5 : 0.0351    recall@10 : 0.0475    recall@20 : 0.0631    ndcg@3 : 0.0217    ndcg@5 : 0.0246    ndcg@10 : 0.0286    ndcg@20 : 0.0326
# 30 Jul 18:30    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-13.pth
# Train     8: 100%|████████████████████| 2293/2293 [07:40<00:00,  4.98it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:38    INFO  epoch 8 training [time: 460.03s, train loss: 19960.8464]
# Train     9: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:46    INFO  epoch 9 training [time: 459.65s, train loss: 19694.9444]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:28<00:00, 18.75it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:47    INFO  epoch 9 evaluating [time: 89.79s, valid_score: 0.065100]
# 30 Jul 18:47    INFO  valid result:
# recall@3 : 0.0283    recall@5 : 0.0359    recall@10 : 0.0488    recall@20 : 0.0651    ndcg@3 : 0.0219    ndcg@5 : 0.0251    ndcg@10 : 0.0292    ndcg@20 : 0.0333
# 30 Jul 18:48    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-13.pth
# Train    10: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 18:55    INFO  epoch 10 training [time: 459.90s, train loss: 19471.4417]
# Train    11: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:03    INFO  epoch 11 training [time: 459.74s, train loss: 19281.1604]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:29<00:00, 18.62it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:04    INFO  epoch 11 evaluating [time: 90.38s, valid_score: 0.065800]
# 30 Jul 19:04    INFO  valid result:
# recall@3 : 0.0284    recall@5 : 0.0363    recall@10 : 0.0491    recall@20 : 0.0658    ndcg@3 : 0.022    ndcg@5 : 0.0252    ndcg@10 : 0.0293    ndcg@20 : 0.0335
# 30 Jul 19:05    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-13.pth
# Train    12: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:12    INFO  epoch 12 training [time: 459.76s, train loss: 19117.3318]
# Train    13: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:20    INFO  epoch 13 training [time: 459.64s, train loss: 18972.1293]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:30<00:00, 18.36it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:22    INFO  epoch 13 evaluating [time: 91.65s, valid_score: 0.066700]
# 30 Jul 19:22    INFO  valid result:
# recall@3 : 0.0285    recall@5 : 0.0366    recall@10 : 0.0496    recall@20 : 0.0667    ndcg@3 : 0.022    ndcg@5 : 0.0253    ndcg@10 : 0.0295    ndcg@20 : 0.0338
# 30 Jul 19:22    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-13.pth
# Train    14: 100%|████████████████████| 2293/2293 [07:40<00:00,  4.98it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:30    INFO  epoch 14 training [time: 460.14s, train loss: 18838.3317]
# Train    15: 100%|████████████████████| 2293/2293 [07:40<00:00,  4.98it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:37    INFO  epoch 15 training [time: 460.04s, train loss: 18718.6546]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:30<00:00, 18.48it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:39    INFO  epoch 15 evaluating [time: 91.06s, valid_score: 0.067000]
# 30 Jul 19:39    INFO  valid result:
# recall@3 : 0.0282    recall@5 : 0.0364    recall@10 : 0.0498    recall@20 : 0.067    ndcg@3 : 0.0219    ndcg@5 : 0.0252    ndcg@10 : 0.0295    ndcg@20 : 0.0339
# 30 Jul 19:39    INFO  Saving current best: saved/SASRecD-Jul-30-2025_17-22-13.pth
# Train    16: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:47    INFO  epoch 16 training [time: 459.83s, train loss: 18607.8237]
# Train    17: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.98it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:54    INFO  epoch 17 training [time: 459.99s, train loss: 18503.2590]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:30<00:00, 18.43it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 19:56    INFO  epoch 17 evaluating [time: 91.29s, valid_score: 0.066600]
# 30 Jul 19:56    INFO  valid result:
# recall@3 : 0.0281    recall@5 : 0.0362    recall@10 : 0.0494    recall@20 : 0.0666    ndcg@3 : 0.0218    ndcg@5 : 0.0252    ndcg@10 : 0.0294    ndcg@20 : 0.0337
# Train    18: 100%|████████████████████| 2293/2293 [07:40<00:00,  4.98it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:04    INFO  epoch 18 training [time: 460.43s, train loss: 18407.7033]
# Train    19: 100%|████████████████████| 2293/2293 [07:40<00:00,  4.98it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:11    INFO  epoch 19 training [time: 460.56s, train loss: 18318.1889]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:30<00:00, 18.47it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:13    INFO  epoch 19 evaluating [time: 91.09s, valid_score: 0.066400]
# 30 Jul 20:13    INFO  valid result:
# recall@3 : 0.0278    recall@5 : 0.036    recall@10 : 0.0493    recall@20 : 0.0664    ndcg@3 : 0.0216    ndcg@5 : 0.025    ndcg@10 : 0.0293    ndcg@20 : 0.0336
# Train    20: 100%|████████████████████| 2293/2293 [07:40<00:00,  4.98it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:20    INFO  epoch 20 training [time: 460.26s, train loss: 18226.4847]
# Train    21: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:28    INFO  epoch 21 training [time: 459.93s, train loss: 18146.0426]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:30<00:00, 18.42it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:30    INFO  epoch 21 evaluating [time: 91.36s, valid_score: 0.065800]
# 30 Jul 20:30    INFO  valid result:
# recall@3 : 0.0277    recall@5 : 0.0358    recall@10 : 0.0489    recall@20 : 0.0658    ndcg@3 : 0.0216    ndcg@5 : 0.0249    ndcg@10 : 0.0291    ndcg@20 : 0.0334
# Train    22: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:37    INFO  epoch 22 training [time: 459.62s, train loss: 18066.2658]
# Train    23: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:45    INFO  epoch 23 training [time: 459.58s, train loss: 17988.6706]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:26<00:00, 19.13it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:46    INFO  epoch 23 evaluating [time: 87.96s, valid_score: 0.065100]
# 30 Jul 20:46    INFO  valid result:
# recall@3 : 0.0274    recall@5 : 0.0353    recall@10 : 0.0481    recall@20 : 0.0651    ndcg@3 : 0.0214    ndcg@5 : 0.0246    ndcg@10 : 0.0287    ndcg@20 : 0.033
# Train    24: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 20:54    INFO  epoch 24 training [time: 459.70s, train loss: 17914.2438]
# Train    25: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:02    INFO  epoch 25 training [time: 459.54s, train loss: 17840.7890]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:28<00:00, 18.89it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:03    INFO  epoch 25 evaluating [time: 89.12s, valid_score: 0.065000]
# 30 Jul 21:03    INFO  valid result:
# recall@3 : 0.0273    recall@5 : 0.0352    recall@10 : 0.0481    recall@20 : 0.065    ndcg@3 : 0.0213    ndcg@5 : 0.0246    ndcg@10 : 0.0287    ndcg@20 : 0.033
# Train    26: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:11    INFO  epoch 26 training [time: 459.71s, train loss: 17767.6695]
# Train    27: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:18    INFO  epoch 27 training [time: 459.96s, train loss: 17697.1271]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:29<00:00, 18.65it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:20    INFO  epoch 27 evaluating [time: 90.26s, valid_score: 0.064100]
# 30 Jul 21:20    INFO  valid result:
# recall@3 : 0.027    recall@5 : 0.0347    recall@10 : 0.0474    recall@20 : 0.0641    ndcg@3 : 0.0211    ndcg@5 : 0.0243    ndcg@10 : 0.0284    ndcg@20 : 0.0326
# Train    28: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:28    INFO  epoch 28 training [time: 459.76s, train loss: 17624.2617]
# Train    29: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:35    INFO  epoch 29 training [time: 459.64s, train loss: 17559.2772]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:27<00:00, 18.98it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:37    INFO  epoch 29 evaluating [time: 88.68s, valid_score: 0.063500]
# 30 Jul 21:37    INFO  valid result:
# recall@3 : 0.0268    recall@5 : 0.0343    recall@10 : 0.0471    recall@20 : 0.0635    ndcg@3 : 0.021    ndcg@5 : 0.0241    ndcg@10 : 0.0283    ndcg@20 : 0.0324
# Train    30: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:44    INFO  epoch 30 training [time: 459.64s, train loss: 17488.0822]
# Train    31: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:52    INFO  epoch 31 training [time: 459.72s, train loss: 17420.5652]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:29<00:00, 18.52it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 21:54    INFO  epoch 31 evaluating [time: 90.89s, valid_score: 0.063300]
# 30 Jul 21:54    INFO  valid result:
# recall@3 : 0.0266    recall@5 : 0.0343    recall@10 : 0.047    recall@20 : 0.0633    ndcg@3 : 0.021    ndcg@5 : 0.0241    ndcg@10 : 0.0282    ndcg@20 : 0.0323
# Train    32: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:01    INFO  epoch 32 training [time: 459.82s, train loss: 17349.7452]
# Train    33: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:09    INFO  epoch 33 training [time: 459.63s, train loss: 17288.8225]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:29<00:00, 18.64it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:10    INFO  epoch 33 evaluating [time: 90.26s, valid_score: 0.062400]
# 30 Jul 22:10    INFO  valid result:
# recall@3 : 0.0264    recall@5 : 0.0337    recall@10 : 0.0463    recall@20 : 0.0624    ndcg@3 : 0.0208    ndcg@5 : 0.0239    ndcg@10 : 0.0279    ndcg@20 : 0.032
# Train    34: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.98it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:18    INFO  epoch 34 training [time: 459.98s, train loss: 17220.6125]
# Train    35: 100%|████████████████████| 2293/2293 [07:40<00:00,  4.98it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:26    INFO  epoch 35 training [time: 460.13s, train loss: 17153.6352]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:27<00:00, 19.09it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:27    INFO  epoch 35 evaluating [time: 88.18s, valid_score: 0.061200]
# 30 Jul 22:27    INFO  valid result:
# recall@3 : 0.0259    recall@5 : 0.0335    recall@10 : 0.0455    recall@20 : 0.0612    ndcg@3 : 0.0205    ndcg@5 : 0.0237    ndcg@10 : 0.0275    ndcg@20 : 0.0315
# Train    36: 100%|████████████████████| 2293/2293 [07:39<00:00,  4.99it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:35    INFO  epoch 36 training [time: 459.97s, train loss: 17090.5208]
# Train    37: 100%|████████████████████| 2293/2293 [07:40<00:00,  4.98it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:43    INFO  epoch 37 training [time: 460.04s, train loss: 17026.3120]
# Evaluate   : 100%|████████████████████| 1664/1664 [01:30<00:00, 18.43it/s, GPU RAM: 37.67 G/39.56 G]
# 30 Jul 22:44    INFO  epoch 37 evaluating [time: 91.29s, valid_score: 0.061000]
# 30 Jul 22:44    INFO  valid result:
# recall@3 : 0.0259    recall@5 : 0.0333    recall@10 : 0.0454    recall@20 : 0.061    ndcg@3 : 0.0205    ndcg@5 : 0.0236    ndcg@10 : 0.0275    ndcg@20 : 0.0314
# 30 Jul 22:44    INFO  Finished training, best eval result in epoch 15
# 30 Jul 22:44    INFO  Loading model structure and parameters from saved/SASRecD-Jul-30-2025_17-22-13.pth
# Evaluate   : 100%|████████████████████| 1664/1664 [01:30<00:00, 18.37it/s, GPU RAM: 37.69 G/39.56 G]
# 30 Jul 22:46    INFO  best valid : {'recall@3': 0.0282, 'recall@5': 0.0364, 'recall@10': 0.0498, 'recall@20': 0.067, 'ndcg@3': 0.0219, 'ndcg@5': 0.0252, 'ndcg@10': 0.0295, 'ndcg@20': 0.0339}
# 30 Jul 22:46    INFO  test result: {'recall@3': 0.0442, 'recall@5': 0.0504, 'recall@10': 0.0605, 'recall@20': 0.074, 'ndcg@3': 0.039, 'ndcg@5': 0.0416, 'ndcg@10': 0.0448, 'ndcg@20': 0.0482}
# 19819.627281427383

# %%
# !cp /content/saved/title_2023_without_side_task.pth /content/drive/MyDrive/

# %%
from google.colab import drive

drive.flush_and_unmount()
